# %%
import os
import sys
import json
import numpy as np
import matplotlib.pyplot as plt

sys.path.insert(0, '../codes/')
import bulkMotion
import misc


font_size=24
plt.rcParams.update({'font.size': font_size})

# %%
ng = 20

# use Aqaba mean angles
head_a = -10.25
head_d = -169.75

bulkMotion.ballpark_ramp(orbit='ASCENDING' , prate=[-15,15], vertical=True, given_inc='table', given_head=[head_a, head_a], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
bulkMotion.ballpark_ramp(orbit='DESCENDING', prate=[-15,15], vertical=True, given_inc='table', given_head=[head_d, head_d], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
# Out:
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "ASCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-10.25, -10.25]
# Incidence angle range: [30.68, 46.24] deg
# Heading   angle range: [-10.25, -10.25] deg
# Average satellite heading  : 349.7500
# Average satellite incidence: 38.4600
# Save to file (EXT=pdf, DPI=300, W/H=3000.0/2100.0 p): ../pic/losRamp_V_bulkmotion_Ascending_20.pdf
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "DESCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-169.75, -169.75]
# Incidence angle range: [30.78, 46.28] deg
# ...

# %%
ng = 20
bulkMotion.ballpark_ramp(orbit='ASCENDING', given_inc='table', given_head=[head_a, head_a], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
bulkMotion.ballpark_ramp(orbit='DESCENDING',given_inc='table', given_head=[head_d, head_d], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
# Out:
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "ASCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-10.25, -10.25]
# Incidence angle range: [30.68, 46.24] deg
# Heading   angle range: [-10.25, -10.25] deg
# Average satellite heading  : 349.7500
# Average satellite incidence: 38.4600
# Save to file (EXT=pdf, DPI=300, W/H=3000.0/2100.0 p): ../pic/losRamp_H_bulkmotion_Ascending_20.pdf
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "DESCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-169.75, -169.75]
# Incidence angle range: [30.78, 46.28] deg
# ...

# %%
ng = 100
bulkMotion.ballpark_ramp(orbit='ASCENDING', given_inc='table', given_head=[head_a, head_a], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
bulkMotion.ballpark_ramp(orbit='DESCENDING',given_inc='table', given_head=[head_d, head_d], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
# Out:
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "ASCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-10.25, -10.25]
# Incidence angle range: [30.68, 46.24] deg
# Heading   angle range: [-10.25, -10.25] deg
# Average satellite heading  : 349.7500
# Average satellite incidence: 38.4600
# Save to file (EXT=pdf, DPI=300, W/H=3000.0/2100.0 p): ../pic/losRamp_H_bulkmotion_Ascending_100.pdf
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "DESCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-169.75, -169.75]
# Incidence angle range: [30.78, 46.28] deg
# ...
