# %%
import os
import sys
import json
import numpy as np
import matplotlib.pyplot as plt

sys.path.insert(0, '../codes/')
import bulkMotion
import misc


font_size=24
plt.rcParams.update({'font.size': font_size})

# %%
ng = 20
bulkMotion.ballpark_ramp(orbit='ASCENDING' , prate=[-15,15], vertical=True, given_inc='table', given_head=[-26.2 , -26.2], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
bulkMotion.ballpark_ramp(orbit='DESCENDING', prate=[-15,15], vertical=True, given_inc='table', given_head=[-167.3,-167.3], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
# Out:
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "ASCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-26.2, -26.2]
# Incidence angle range: [30.68, 46.24] deg
# Heading   angle range: [-26.20, -26.20] deg
# Average satellite heading  : 333.8000
# Average satellite incidence: 38.4600
# Save to file: ../pic/losRamp_V_bulkmotion_Ascending_20.pdf
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "DESCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-167.3, -167.3]
# Incidence angle range: [30.78, 46.28] deg
# Heading   angle range: [-167.30, -167.30] deg
# ...

# %%
ng = 20
bulkMotion.ballpark_ramp(orbit='ASCENDING', given_inc='table', given_head=[-26.2 , -26.2], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
bulkMotion.ballpark_ramp(orbit='DESCENDING',given_inc='table', given_head=[-167.3,-167.3], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
# Out:
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "ASCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-26.2, -26.2]
# Incidence angle range: [30.68, 46.24] deg
# Heading   angle range: [-26.20, -26.20] deg
# Average satellite heading  : 333.8000
# Average satellite incidence: 38.4600
# Save to file: ../pic/losRamp_H_bulkmotion_Ascending_20.pdf
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "DESCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-167.3, -167.3]
# Incidence angle range: [30.78, 46.28] deg
# Heading   angle range: [-167.30, -167.30] deg
# ...

# %%
ng = 100
bulkMotion.ballpark_ramp(orbit='ASCENDING', given_inc='table', given_head=[-26.2 , -26.2], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
bulkMotion.ballpark_ramp(orbit='DESCENDING',given_inc='table', given_head=[-167.3,-167.3], length=500, width=300, Nth=ng, Npr=ng, pic_dir='../pic')
# Out:
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "ASCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-26.2, -26.2]
# Incidence angle range: [30.68, 46.24] deg
# Heading   angle range: [-26.20, -26.20] deg
# Average satellite heading  : 333.8000
# Average satellite incidence: 38.4600
# Save to file: ../pic/losRamp_H_bulkmotion_Ascending_100.pdf
# No geometry file (.h5) specified!
# Please run guess_geom(orbit, given_inc, given_head, length, width) with default/custom angles and orbit
# Note that this method is only a ballpark estimate, not recommended
# Initialize a simple "DESCENDING" geometry with dimension (500, 300)
# Given incidence: table
# Given heading: [-167.3, -167.3]
# Incidence angle range: [30.78, 46.28] deg
# Heading   angle range: [-167.30, -167.30] deg
# ...
